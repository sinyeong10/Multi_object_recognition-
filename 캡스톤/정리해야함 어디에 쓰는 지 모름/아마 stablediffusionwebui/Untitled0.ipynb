# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 17850, done.
# remote: Total 17850 (delta 0), reused 0 (delta 0), pack-reused 17850
# Receiving objects: 100% (17850/17850), 28.22 MiB | 23.51 MiB/s, done.
# Resolving deltas: 100% (12502/12502), done.

# %%
ls
# Out:
# sample_data/  stable-diffusion-webui/

# %%
cd /content/stable-diffusion-webui
# Out:
# /content/stable-diffusion-webui

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting blendmodes
#   Downloading blendmodes-2022-py3-none-any.whl (10 kB)
# Collecting accelerate
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 16.9 MB/s eta 0:00:00
# Collecting basicsr
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 KB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fonts
#   Downloading fonts-0.0.3-py3-none-any.whl (4.2 kB)
# Collecting font-roboto
#   Downloading font-roboto-0.0.1.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gfpgan
#   Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 KB 6.4 MB/s eta 0:00:00
# Collecting gradio==3.23
#   Downloading gradio-3.23.0-py3-none-any.whl (15.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 47.2 MB/s eta 0:00:00
# Collecting invisible-watermark
#   Downloading invisible_watermark-0.1.5-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (1.22.4)
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (4.7.0.72)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (2.27.1)
# Collecting piexif
#   Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (8.4.0)
# Collecting pytorch_lightning==1.7.7
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 KB 54.5 MB/s eta 0:00:00
# Collecting realesrgan
#   Downloading realesrgan-0.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: scikit-image>=0.19 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (0.19.3)
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 39.8 MB/s eta 0:00:00
# Collecting transformers==4.25.1
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 93.9 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 20)) (1.13.1+cu116)
# Collecting einops
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 5.9 MB/s eta 0:00:00
# Collecting jsonmerge
#   Downloading jsonmerge-1.9.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting clean-fid
#   Downloading clean_fid-0.1.35-py3-none-any.whl (26 kB)
# Collecting resize-right
#   Downloading resize_right-0.0.2-py3-none-any.whl (8.9 kB)
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting kornia
#   Downloading kornia-0.6.11-py2.py3-none-any.whl (628 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.1/628.1 KB 46.6 MB/s eta 0:00:00
# Collecting lark
#   Downloading lark-1.1.5-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 KB 13.5 MB/s eta 0:00:00
# Collecting inflection
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting GitPython
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 19.6 MB/s eta 0:00:00
# Collecting torchsde
#   Downloading torchsde-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 8.4 MB/s eta 0:00:00
# Collecting safetensors
#   Downloading safetensors-0.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 32)) (5.9.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 33)) (13.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (1.4.4)
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (4.2.2)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.8 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.9 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (2.1.2)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting huggingface-hub>=0.13.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 22.6 MB/s eta 0:00:00
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 10.1 MB/s eta 0:00:00
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (3.7.1)
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (2023.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (1.10.7)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio==3.23->-r requirements.txt (line 7)) (3.1.2)
# Collecting fastapi
#   Downloading fastapi-0.95.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 KB 6.7 MB/s eta 0:00:00
# Collecting orjson
#   Downloading orjson-3.8.9-cp39-cp39-manylinux_2_28_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.1/144.1 KB 17.1 MB/s eta 0:00:00
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 45.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (23.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.12.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (4.65.0)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from timm==0.4.12->-r requirements.txt (line 18)) (0.14.1+cu116)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 61.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (3.10.7)
# Collecting deprecation<3,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting Pillow
#   Downloading Pillow-9.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 59.6 MB/s eta 0:00:00
# Collecting aenum<4,>=3.1.7
#   Downloading aenum-3.1.12-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 KB 10.3 MB/s eta 0:00:00
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.18.3)
# Collecting lmdb
#   Downloading lmdb-1.4.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.9/305.9 KB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (4.7.0.72)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (1.10.1)
# Collecting tb-nightly
#   Downloading tb_nightly-2.13.0a20230330-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 72.0 MB/s eta 0:00:00
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 20.6 MB/s eta 0:00:00
# Collecting facexlib>=0.2.5
#   Downloading facexlib-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 KB 305.0 kB/s eta 0:00:00
# Collecting onnxruntime
#   Downloading onnxruntime-1.14.1-cp39-cp39-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 78.9 MB/s eta 0:00:00
# Collecting onnx
#   Downloading onnx-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from invisible-watermark->-r requirements.txt (line 8)) (1.4.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (2.0.12)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (2023.3.21)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (3.0)
# Requirement already satisfied: jsonschema>2.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonmerge->-r requirements.txt (line 22)) (4.3.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 9.2 MB/s eta 0:00:00
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Collecting boltons>=20.2.1
#   Downloading boltons-23.0.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->-r requirements.txt (line 33)) (2.14.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.23->-r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.23->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (0.56.4)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 22.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 26.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.23->-r requirements.txt (line 7)) (22.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 11.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>2.4.0->jsonmerge->-r requirements.txt (line 22)) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.23->-r requirements.txt (line 7)) (0.1.2)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.23->-r requirements.txt (line 7)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.23->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.40.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (67.6.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.4.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.53.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.17.0)
# Collecting starlette<0.27.0,>=0.26.1
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 KB 9.3 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 10.3 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.23->-r requirements.txt (line 7)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.23->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.23->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.23->-r requirements.txt (line 7)) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.23->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.23->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (1.11.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/dist-packages (from onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (23.3.3)
# Collecting tb-nightly
#   Downloading tb_nightly-2.13.0a20230329-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 69.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230328-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 84.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230327-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 75.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230326-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 60.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230325-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 50.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230324-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 60.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230321-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 61.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230319-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 62.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230317-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 64.1 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio==3.23->-r requirements.txt (line 7)) (8.1.3)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.3.1)
# Collecting anyio<5.0,>=3.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->gradio==3.23->-r requirements.txt (line 7)) (3.15.0)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (6.1.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (0.39.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.2.2)
# Building wheels for collected packages: basicsr, font-roboto, antlr4-python3-runtime, jsonmerge, ffmpy, filterpy
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214839 sha256=4bd8e5419f43f087491b4533be888b5fd5205bddfff102ed039be5d9d64221d2
#   Stored in directory: /root/.cache/pip/wheels/42/d6/3d/6d8c4b8fabeb93dd442eb255f133e8928c75d903fe20e9472c
#   Building wheel for font-roboto (setup.py) ... done
#   Created wheel for font-roboto: filename=font_roboto-0.0.1-py3-none-any.whl size=2359752 sha256=3f8bb164e9e0141f830ea2ddfa03ffb98762c062cbe80aa6099d9b236aa727b2
#   Stored in directory: /root/.cache/pip/wheels/26/36/01/d5840af8f7419a9361142426ff7709b529f8e3624ae2248c68
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=fe016d0cf00c5f150dc4f7db0a53499fab870b83f52d3df34e0624ae0842b6f3
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for jsonmerge (setup.py) ... done
#   Created wheel for jsonmerge: filename=jsonmerge-1.9.0-py3-none-any.whl size=18625 sha256=667b9639552175032cb5ac730e31c77811428804073cae2af364a976ed1cdf81
#   Stored in directory: /root/.cache/pip/wheels/09/0f/dd/bd5a8b81ed1feef7d08fea857f7bee591e481a484e6bee317a
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4707 sha256=e0053f4296fab161497aa0e734b1b47035e0254aab17925be6d888e0dc881266
#   Stored in directory: /root/.cache/pip/wheels/91/e2/96/f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110473 sha256=8e356c612c15224ac4a859c55c23afce95d593a62a0e413ecae929e209ec5a31
#   Stored in directory: /root/.cache/pip/wheels/53/e6/de/a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
# Successfully built basicsr font-roboto antlr4-python3-runtime jsonmerge ffmpy filterpy
# Installing collected packages: yapf, trampoline, tokenizers, safetensors, rfc3986, resize-right, pydub, lmdb, lark, fonts, font-roboto, ffmpy, boltons, antlr4-python3-runtime, aenum, addict, websockets, uc-micro-py, sniffio, smmap, semantic-version, python-multipart, pyDeprecate, Pillow, piexif, orjson, onnx, omegaconf, multidict, inflection, humanfriendly, h11, frozenlist, einops, deprecation, async-timeout, aiofiles, yarl, uvicorn, torchsde, torchmetrics, torchdiffeq, mdit-py-plugins, linkify-it-py, kornia, jsonmerge, huggingface-hub, gitdb, coloredlogs, blendmodes, anyio, aiosignal, accelerate, transformers, timm, starlette, onnxruntime, httpcore, GitPython, filterpy, clean-fid, aiohttp, tb-nightly, invisible-watermark, httpx, fastapi, facexlib, pytorch_lightning, gradio, basicsr, gfpgan, realesrgan
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# Successfully installed GitPython-3.1.31 Pillow-9.4.0 accelerate-0.18.0 addict-2.4.0 aenum-3.1.12 aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 anyio-3.6.2 async-timeout-4.0.2 basicsr-1.4.2 blendmodes-2022 boltons-23.0.0 clean-fid-0.1.35 coloredlogs-15.0.1 deprecation-2.1.0 einops-0.6.0 facexlib-0.2.5 fastapi-0.95.0 ffmpy-0.3.0 filterpy-1.4.5 font-roboto-0.0.1 fonts-0.0.3 frozenlist-1.3.3 gfpgan-1.3.8 gitdb-4.0.10 gradio-3.23.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 huggingface-hub-0.13.3 humanfriendly-10.0 inflection-0.5.1 invisible-watermark-0.1.5 jsonmerge-1.9.0 kornia-0.6.11 lark-1.1.5 linkify-it-py-2.0.0 lmdb-1.4.0 mdit-py-plugins-0.3.3 multidict-6.0.4 omegaconf-2.3.0 onnx-1.13.1 onnxruntime-1.14.1 orjson-3.8.9 piexif-1.1.3 pyDeprecate-0.3.2 pydub-0.25.1 python-multipart-0.0.6 pytorch_lightning-1.7.7 realesrgan-0.3.0 resize-right-0.0.2 rfc3986-1.5.0 safetensors-0.3.0 semantic-version-2.10.0 smmap-5.0.0 sniffio-1.3.0 starlette-0.26.1 tb-nightly-2.13.0a20230317 timm-0.4.12 tokenizers-0.13.2 torchdiffeq-0.2.3 torchmetrics-0.11.4 torchsde-0.2.5 trampoline-0.1.2 transformers-4.25.1 uc-micro-py-1.0.1 uvicorn-0.21.1 websockets-10.4 yapf-0.32.0 yarl-1.8.2

# %%
# !apt-get install docker.io #docker 클라이언트 설치
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base iptables
#   libidn11 libip6tc2 libnetfilter-conntrack3 libnfnetlink0 libnftnl11 netbase
#   netcat netcat-openbsd pigz runc ubuntu-fan
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils ifupdown aufs-tools btrfs-progs
#   cgroupfs-mount | cgroup-lite debootstrap docker-doc rinse zfs-fuse
#   | zfsutils firewalld nftables
# The following NEW packages will be installed:
#   apparmor bridge-utils containerd dns-root-data dnsmasq-base docker.io
#   iptables libidn11 libip6tc2 libnetfilter-conntrack3 libnfnetlink0 libnftnl11
#   netbase netcat netcat-openbsd pigz runc ubuntu-fan
# 0 upgraded, 18 newly installed, 0 to remove and 23 not upgraded.
# Need to get 67.1 MB of archives.
# After this operation, 298 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 pigz amd64 2.4-1 [57.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 netbase all 6.1 [13.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 netcat-openbsd amd64 1.206-1ubuntu1 [37.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apparmor amd64 2.13.3-7ubuntu5.2 [502 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libip6tc2 amd64 1.8.4-3ubuntu2 [19.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libnfnetlink0 amd64 1.0.1-3build1 [13.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libnetfilter-conntrack3 amd64 1.0.7-2 [41.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libnftnl11 amd64 1.1.5-1 [57.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 iptables amd64 1.8.4-3ubuntu2 [390 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 bridge-utils amd64 1.6-2ubuntu1 [30.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 runc amd64 1.1.4-0ubuntu1~20.04.1 [3,817 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 containerd amd64 1.6.12-0ubuntu1~20.04.1 [31.4 MB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 dns-root-data all 2019052802 [5,300 B]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libidn11 amd64 1.33-2.2ubuntu2 [46.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 dnsmasq-base amd64 2.80-1.1ubuntu1.6 [315 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 docker.io amd64 20.10.21-0ubuntu1~20.04.1 [30.3 MB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/universe amd64 netcat all 1.206-1ubuntu1 [2,172 B]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 ubuntu-fan all 0.12.13ubuntu0.1 [34.4 kB]
# Fetched 67.1 MB in 3s (19.4 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package pigz.
# (Reading database ... 128288 files and directories currently installed.)
# Preparing to unpack .../00-pigz_2.4-1_amd64.deb ...
# Unpacking pigz (2.4-1) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../01-netbase_6.1_all.deb ...
# Unpacking netbase (6.1) ...
# Selecting previously unselected package netcat-openbsd.
# Preparing to unpack .../02-netcat-openbsd_1.206-1ubuntu1_amd64.deb ...
# Unpacking netcat-openbsd (1.206-1ubuntu1) ...
# Selecting previously unselected package apparmor.
# Preparing to unpack .../03-apparmor_2.13.3-7ubuntu5.2_amd64.deb ...
# Unpacking apparmor (2.13.3-7ubuntu5.2) ...
# Selecting previously unselected package libip6tc2:amd64.
# Preparing to unpack .../04-libip6tc2_1.8.4-3ubuntu2_amd64.deb ...
# Unpacking libip6tc2:amd64 (1.8.4-3ubuntu2) ...
# Selecting previously unselected package libnfnetlink0:amd64.
# Preparing to unpack .../05-libnfnetlink0_1.0.1-3build1_amd64.deb ...
# Unpacking libnfnetlink0:amd64 (1.0.1-3build1) ...
# Selecting previously unselected package libnetfilter-conntrack3:amd64.
# Preparing to unpack .../06-libnetfilter-conntrack3_1.0.7-2_amd64.deb ...
# Unpacking libnetfilter-conntrack3:amd64 (1.0.7-2) ...
# Selecting previously unselected package libnftnl11:amd64.
# Preparing to unpack .../07-libnftnl11_1.1.5-1_amd64.deb ...
# Unpacking libnftnl11:amd64 (1.1.5-1) ...
# Selecting previously unselected package iptables.
# Preparing to unpack .../08-iptables_1.8.4-3ubuntu2_amd64.deb ...
# Unpacking iptables (1.8.4-3ubuntu2) ...
# Selecting previously unselected package bridge-utils.
# Preparing to unpack .../09-bridge-utils_1.6-2ubuntu1_amd64.deb ...
# Unpacking bridge-utils (1.6-2ubuntu1) ...
# Selecting previously unselected package runc.
# Preparing to unpack .../10-runc_1.1.4-0ubuntu1~20.04.1_amd64.deb ...
# Unpacking runc (1.1.4-0ubuntu1~20.04.1) ...
# Selecting previously unselected package containerd.
# Preparing to unpack .../11-containerd_1.6.12-0ubuntu1~20.04.1_amd64.deb ...
# Unpacking containerd (1.6.12-0ubuntu1~20.04.1) ...
# Selecting previously unselected package dns-root-data.
# Preparing to unpack .../12-dns-root-data_2019052802_all.deb ...
# Unpacking dns-root-data (2019052802) ...
# Selecting previously unselected package libidn11:amd64.
# Preparing to unpack .../13-libidn11_1.33-2.2ubuntu2_amd64.deb ...
# Unpacking libidn11:amd64 (1.33-2.2ubuntu2) ...
# Selecting previously unselected package dnsmasq-base.
# Preparing to unpack .../14-dnsmasq-base_2.80-1.1ubuntu1.6_amd64.deb ...
# Unpacking dnsmasq-base (2.80-1.1ubuntu1.6) ...
# Selecting previously unselected package docker.io.
# Preparing to unpack .../15-docker.io_20.10.21-0ubuntu1~20.04.1_amd64.deb ...
# Unpacking docker.io (20.10.21-0ubuntu1~20.04.1) ...
# Selecting previously unselected package netcat.
# Preparing to unpack .../16-netcat_1.206-1ubuntu1_all.deb ...
# Unpacking netcat (1.206-1ubuntu1) ...
# Selecting previously unselected package ubuntu-fan.
# Preparing to unpack .../17-ubuntu-fan_0.12.13ubuntu0.1_all.deb ...
# Unpacking ubuntu-fan (0.12.13ubuntu0.1) ...
# Setting up libip6tc2:amd64 (1.8.4-3ubuntu2) ...
# Setting up netcat-openbsd (1.206-1ubuntu1) ...
# update-alternatives: using /bin/nc.openbsd to provide /bin/nc (nc) in auto mode
# Setting up libnftnl11:amd64 (1.1.5-1) ...
# Setting up netcat (1.206-1ubuntu1) ...
# Setting up runc (1.1.4-0ubuntu1~20.04.1) ...
# Setting up dns-root-data (2019052802) ...
# Setting up apparmor (2.13.3-7ubuntu5.2) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up libidn11:amd64 (1.33-2.2ubuntu2) ...
# Setting up bridge-utils (1.6-2ubuntu1) ...
# Setting up pigz (2.4-1) ...
# Setting up libnfnetlink0:amd64 (1.0.1-3build1) ...
# Setting up netbase (6.1) ...
# Setting up containerd (1.6.12-0ubuntu1~20.04.1) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/containerd.service → /lib/systemd/system/containerd.service.
# Setting up libnetfilter-conntrack3:amd64 (1.0.7-2) ...
# Setting up iptables (1.8.4-3ubuntu2) ...
# update-alternatives: using /usr/sbin/iptables-legacy to provide /usr/sbin/iptables (iptables) in auto mode
# update-alternatives: using /usr/sbin/ip6tables-legacy to provide /usr/sbin/ip6tables (ip6tables) in auto mode
# update-alternatives: using /usr/sbin/arptables-nft to provide /usr/sbin/arptables (arptables) in auto mode
# update-alternatives: using /usr/sbin/ebtables-nft to provide /usr/sbin/ebtables (ebtables) in auto mode
# Setting up docker.io (20.10.21-0ubuntu1~20.04.1) ...
# Adding group `docker' (GID 113) ...
# Done.
# Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /lib/systemd/system/docker.service.
# Created symlink /etc/systemd/system/sockets.target.wants/docker.socket → /lib/systemd/system/docker.socket.
# invoke-rc.d: unknown initscript, /etc/init.d/docker not found.
# invoke-rc.d: could not determine current runlevel
# Setting up dnsmasq-base (2.80-1.1ubuntu1.6) ...
# Setting up ubuntu-fan (0.12.13ubuntu0.1) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/ubuntu-fan.service → /lib/systemd/system/ubuntu-fan.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Processing triggers for systemd (245.4-4ubuntu3.20) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for dbus (1.12.16-2ubuntu2.3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
# !pwd
# Out:
# /content/stable-diffusion-webui

# %%
ls
# Out:
# CODEOWNERS             localizations/             test/
# configs/               models/                    textual_inversion_templates/
# embeddings/            modules/                   webui.bat
# environment-wsl2.yaml  README.md                  webui-macos-env.sh
# extensions/            requirements.txt           webui.py
# extensions-builtin/    requirements_versions.txt  webui.sh*
# html/                  screenshot.png             webui-user.bat
# javascript/            script.js                  webui-user.sh
# launch.py              scripts/
# LICENSE.txt            style.css

# %%
# !docker build -t stable-diffusion-webui .
# Out:
# unable to prepare context: unable to evaluate symlinks in Dockerfile path: lstat /content/stable-diffusion-webui/Dockerfile: no such file or directory
